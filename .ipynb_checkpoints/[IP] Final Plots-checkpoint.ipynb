# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import signal
from glob import glob

# %% [markdown]
# ## Training Zorb
# - trained, plot looks wrong
# - wrong geometry (what granularity do we need?)

# %%
f = open('guassian.zrb', 'rb')
f.seek(32) # skipping header (32 bytes)
hist = np.fromfile(f, dtype='uint8')

# %%
pd.Series(hist).describe()
# Out:
# count    524288.000000
# mean          3.160286
# std          22.076733
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max         255.000000
# dtype: float64

# %%
#basic visualization of histogram zorb created
plt.hist(hist, bins=50);

# %% [markdown]
# **Questions for Russell:**
#     - What should granularity be? Why is geo=1 wrong?
#     - During trianing mode=2 (this means absorb right?)

# %% [markdown]
# ## Chirp and Normal Noise Needle Types
# - generalized rand_hay.py, scan.py, plot_results.py to create, scan, and plot chirp and noise needletypes
# - created 1000 chirp haystacks per db level
# - Reran scan and plots with new signal types
#
# Running agnentroscan:
# * entropy = ("i")
# * geo = 0 vs. 2
# * rank = 1
# * out_format = 3
# * sweep = 250000 (same as duty cycle)

# %% [markdown]
# ### Visualization of Linear Chirp Signal
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Chirp at -20db (geo=0)
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Sine at -20db (geo=0)
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Chirp at -10db (geo=0)
# ![chirp_-10bd](-10db_i_chirp_plots.png)

# %% [markdown]
# ## Chirp at -10db (geo=0)
# ![sine_-10bd](-10db_i_sine_plots.png)

# %% [markdown]
# ## Chirp at -5db (geo=0)
# ![chirp at -5](-5db_i_chirp_plots.png)

# %% [markdown]
# ## Sine at -5db (geo=0)
# ![chirp at -5](-5db_i_sine_plots.png)

# %% [markdown]
# ## Comparing with power method (ROC curves)
# - integrated power_detector.py to work with current workflow (haystacks dir with npy/txt files, results.csv, eplots.png)
# - figure out why int8 conversion is causing such discrepancies in power_detector method?
# - TO DO: create ROC.py for both entropy and power input

# %% [markdown]
# chirp at 10db:
# ![image.png](attachment:image.png)

# %% [markdown]
# sine at 10db:
# ![image.png](attachment:image.png)

# %% [markdown]
# sine at -10db:
# ![image.png](attachment:image.png)

# %% [markdown]
# chirp at -10db:
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Sweep Test
# - Reran for 50% duty cycle (5000 samples)
#
# Running agnentroscan:
# * entropy = ("i")
# * geo = 0
# * rank = 1
# * out_format = 3

# %% [markdown]
# ### 25% DUTY CYCLE
# ![picture](25dc_i__plot.png)

# %% [markdown]
# ### 50% DUTY CYCLE
# ![50%dutycycle](i__plot.png)

# %% [markdown]
# !
